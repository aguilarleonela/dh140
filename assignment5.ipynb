# %%
import requests

# %%
response = requests.get('https://corgis-edu.github.io//corgis/csv/')

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n    <head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\n    \n    \n\n    <title>CORGIS Datasets Project</title>\n    <meta name="description" content="\n\n\n\n\n\n\n            Github Pages for CORGIS Datasets Project">\n    <link rel="canonical" href="https://corgis-edu.github.io//corgis/csv/">\n\n    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css">\n    <link rel="stylesheet" href="https://code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">\n    <link rel="stylesheet" href="/corgis/assets/css/main.css">\n\n    \n\n    \n\n    <script src="/corgis/assets/js/jquery-3.3.1.min.js"></script>\n    <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.min.js"\n            integrity="sha256-VazP97ZCwtekAsvgPBSUwPFKdrwD3unUfSGVYrahUqU="\n            crossori
# ...

# %%
from bs4 import BeautifulSoup

# %%
html_string = response.text

document = BeautifulSoup(html_string, "html.parser")

document.find('a')
# Out:
# <a class="site-logo" href="/corgis/" rel="home" title="CORGIS Datasets Project">
# <img alt="CORGIS Datasets Project" class="site-logo-img animated fadeInDown" src="/corgis/images/logo.png"/>
# </a>

# %%
document.find("a")
# Out:
# <a class="site-logo" href="/corgis/" rel="home" title="CORGIS Datasets Project">
# <img alt="CORGIS Datasets Project" class="site-logo-img animated fadeInDown" src="/corgis/images/logo.png"/>
# </a>

# %%
document.find("a").attrs
# Out:
# {'href': '/corgis/',
#  'class': ['site-logo'],
#  'rel': ['home'],
#  'title': 'CORGIS Datasets Project'}

# %%
document
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>CORGIS Datasets Project</title>
# <meta content="
#
#
#
#
#
#
#             Github Pages for CORGIS Datasets Project" name="description"/>
# <link href="https://corgis-edu.github.io//corgis/csv/" rel="canonical"/>
# <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
# <link href="/corgis/assets/css/main.css" rel="stylesheet"/>
# <script src="/corgis/assets/js/jquery-3.3.1.min.js"></script>
# <script crossorigin="anonymous" integrity="sha256-VazP97ZCwtekAsvgPBSUwPFKdrwD3unUfSGVYrahUqU=" src="https://code.jquery.com/ui/1.12.1/jquery-ui.min.js"></script>
# ...

# %%
type(document)
# Out:
# bs4.BeautifulSoup

# %%
document.find_all('a')
# Out:
# [<a class="site-logo" href="/corgis/" rel="home" title="CORGIS Datasets Project">
#  <img alt="CORGIS Datasets Project" class="site-logo-img animated fadeInDown" src="/corgis/images/logo.png"/>
#  </a>,
#  <a class="dataset-link float-left" href="aids/">
#  <img alt="Aids" class="img-thumbnail m-2" src="/corgis//images/datasets/aids-icon.png"/>
#  </a>,
#  <a class="dataset-link" href="aids/">
#  <h3>Aids</h3>
#  </a>,
#  <a class="dataset-link" href="aids/"><em>View</em></a>,
#  <a class="dataset-link float-left" href="airlines/">
#  <img alt="Airlines" class="img-thumbnail m-2" src="/corgis//images/datasets/airlines-icon.png"/>
#  </a>,
#  <a class="dataset-link" href="airlines/">
#  <h3>Airlines</h3>
#  </a>,
#  <a class="dataset-link" href="airlines/"><em>View</em></a>,
#  <a class="dataset-link float-left" href="billionaires/">
#  <img alt="Billionaires" class="img-thumbnail m-2" src="/corgis//images/datasets/billionaires-icon.png"/>
#  </a>,
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://corgis-edu.github.io/corgis/datasets/csv/school_scores/school_scores.csv')

# %%
df.sample
# Out:
# <bound method NDFrame.sample of      Year State.Code     State.Name  Total.Math  Total.Test-takers  \
# 0    2005         AL        Alabama         559               3985
# 1    2005         AK         Alaska         519               3996
# 2    2005         AZ        Arizona         530              18184
# 3    2005         AR       Arkansas         552               1600
# 4    2005         CA     California         522             186552
# ..    ...        ...            ...         ...                ...
# 572  2015         VA       Virginia         517              59621
# 573  2015         WA     Washington         511              44423
# 574  2015         WV  West Virginia         500               2501
# 575  2015         WI      Wisconsin         606               2277
# 576  2015         WY        Wyoming         587                181
#
#      Total.Verbal  Academic Subjects.Arts/Music.Average GPA  \
# 0             567                                      3.92
# ...

# %%
def pdcorgis(a):
    df = pdcorgis("Classics")
    a = a.lower()
    print (a)
    response_ = requests.get('https://corgis-edu.github.io/corgis/datasets/csv/school_scores/school_scores.csv')
